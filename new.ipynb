# %%
import os

# 1. Define the Project Structure
project_name = "Ghana_Maize_Project"

folders = [
    f"{project_name}/data/raw",
    f"{project_name}/data/processed",
    f"{project_name}/data/final",
    f"{project_name}/models",
    f"{project_name}/notebooks",
    f"{project_name}/reports/figures",
    f"{project_name}/webapp/.streamlit"
]

files = {
    f"{project_name}/README.md": 
        "# Ghana Maize Yield Prediction\n\nPredicting maize yield using Machine Learning, Satellite Weather Data, and Soil Analysis.",
    
    f"{project_name}/requirements.txt": 
        "pandas\nnumpy\nscikit-learn\njoblib\nstreamlit\ngeopy\nmatplotlib\nseaborn\npython-docx",
    
    f"{project_name}/.gitignore": 
        "__pycache__/\n*.pyc\n.ipynb_checkpoints/\n*.pkl\n.DS_Store",
    
    f"{project_name}/webapp/app.py": 
        "# This is where your Streamlit Web App code will go.\nimport streamlit as st\n\nst.title('Ghana Maize Predictor')"
}

# 2. Build the Structure
print(f"--- BUILDING '{project_name}' ---")

# Create Folders
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"📁 Created: {folder}/")

# Create Files
for filepath, content in files.items():
    with open(filepath, "w") as f:
        f.write(content)
    print(f"📄 Created: {filepath}")

print("\n✅ PROJECT SKELETON READY!")
print(f"👉 Go to the '{project_name}' folder to start working.")
# Out:
# --- BUILDING 'Ghana_Maize_Project' ---
# 📁 Created: Ghana_Maize_Project/data/raw/
# 📁 Created: Ghana_Maize_Project/data/processed/
# 📁 Created: Ghana_Maize_Project/data/final/
# 📁 Created: Ghana_Maize_Project/models/
# 📁 Created: Ghana_Maize_Project/notebooks/
# 📁 Created: Ghana_Maize_Project/reports/figures/
# 📁 Created: Ghana_Maize_Project/webapp/.streamlit/
# 📄 Created: Ghana_Maize_Project/README.md
# 📄 Created: Ghana_Maize_Project/requirements.txt
# 📄 Created: Ghana_Maize_Project/.gitignore
# 📄 Created: Ghana_Maize_Project/webapp/app.py
#
# ✅ PROJECT SKELETON READY!
# 👉 Go to the 'Ghana_Maize_Project' folder to start working.
